# %%
import pandas as pd 
import os
from sqlalchemy import create_engine

# %%
empresas = pd.read_csv('../../files/spreadsheets/empresas.csv',sep=";")

# %%
engine = create_engine("sqlite:///../../files/dataMirrors/empresas.db", echo=True)
sqlite_connection = engine.connect()

sqlite_table = "Empresas"
empresas.to_sql(sqlite_table, sqlite_connection, if_exists='fail')

sqlite_connection.close()
# Out:
# 2020-12-17 18:27:52,673 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-12-17 18:27:52,675 INFO sqlalchemy.engine.base.Engine ()
# 2020-12-17 18:27:52,677 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-12-17 18:27:52,678 INFO sqlalchemy.engine.base.Engine ()
# 2020-12-17 18:27:52,751 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("Empresas")
# 2020-12-17 18:27:52,753 INFO sqlalchemy.engine.base.Engine ()
# 2020-12-17 18:27:52,757 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("Empresas")
# 2020-12-17 18:27:52,763 INFO sqlalchemy.engine.base.Engine ()
# 2020-12-17 18:27:52,793 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE "Empresas" (
# 	"index" BIGINT,
# 	cd_cnpj BIGINT,
# 	fl_matriz BIGINT,
# 	dt_abertura TEXT,
# 	nm_razao_social TEXT,
# 	cd_natureza_juridica BIGINT,
# 	de_natureza_juridica TEXT,
# 	nm_logradouro TEXT,
# 	nu_logradouro TEXT,
# ...

# %%
import pymongo

client = pymongo.MongoClient("mongodb+srv://admin:@Admin123+@cluster0.xweyb.mongodb.net/bineoway?retryWrites=true&w=majority")
db = client.test


print(db)

client = MongoClient(URL)
database = client['YOUR_DB_NAME']
collection = database['your_collection']

def csv_to_json(filename, header=None):
    data = pd.read_csv(filename, header=header)
    return data.to_dict('records')

collection.insert_many(csv_to_json(setor))
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# <ipython-input-7-e995785af112> in <module>
#       1 import pymongo
#       2
# ----> 3 client = pymongo.MongoClient("mongodb+srv://admin:@Admin123+@cluster0.xweyb.mongodb.net/bineoway?retryWrites=true&w=majority")
#       4 db = client.test
#       5
#
# C:\Excecao\Anaconda3\lib\site-packages\pymongo\mongo_client.py in __init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     637                     timeout = common.validate_timeout_or_none_or_zero(
#     638                         keyword_opts.cased_key("connecttimeoutms"), timeout)
# --> 639                 res = uri_parser.parse_uri(
#     640                     entity, port, validate=True, warn=True, normalize=False,
#     641                     connect_timeout=timeout)
#
# ...

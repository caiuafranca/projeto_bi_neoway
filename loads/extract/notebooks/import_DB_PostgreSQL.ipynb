# %%
import pandas as pd 
import psycopg2
import os
from sqlalchemy import create_engine

empresas = pd.read_csv('../../files/spreadsheets/empresas.csv',sep=";")

engine = create_engine('postgresql://rbqbmviohlfhzg:a42f5173184f6966fb51cfa3005b0e99c87e77b0b6a985621229035c557889e3@ec2-54-211-238-131.compute-1.amazonaws.com:5432/d7rcbpbjbknbs3')

#engine = create_engine("sqlite:///../../files/dataMirrors/empresas.db", echo=True)
sqlite_connection = engine.connect()

sqlite_table = "Empresas"
empresas.to_sql(sqlite_table, sqlite_connection, if_exists='fail')

sqlite_connection.close()
